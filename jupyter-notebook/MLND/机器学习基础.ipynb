# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 读取csv
# ```
# data = pd.read_csv('file_name.csv')
# ```

# %% [markdown]
# ## 在sklearn中训练模型
# * 逻辑回归
# ```
# from sklearn.linear_model import LogisticRegression
# classifier = LogisticRegression()
# classifier.fit(X, y)
# ```
# * 神经网络
# ```
# from sklearn.neural_network import MLPClassifier
# classifier = MLPClassifier()
# classifier.fit(X, y)
# ```
# * 决策树
# ```
# from sklearn.tree import DecisionTreeClassifier
# classifier = DecisionTreeClassifier()
# classifier.fit(X, y)
# ```
# * 神经网络
# ```
# from sklearn.svm import SVC
# classifier = SVC()
# classifier.fit(X, y)
# ```
#
# ## 交叉验证，自动调整模型
# ```
# from sklearn.cross_validation import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
# ```

# %% [markdown]
# ## 评估指标
# * 混淆矩阵
# ![%E6%B7%B7%E6%B7%86%E7%9F%A9%E9%98%B5.jpg](attachment:%E6%B7%B7%E6%B7%86%E7%9F%A9%E9%98%B5.jpg)
#
# * 准确率
# ```
# accuracy：分类成功的标签占全部标签的比例
# ```
# * 精度
# ```
# precision：分类为真的标签中，实际为真的标签的占比
# ```
# * 召回率
# ```
# recall：实际为真的标签中，有多少被正确分类的
# ```
# * F1得分
# ```
# 精度和召回率的调和平均数
# ```
# ![F1.jpg](attachment:F1.jpg)
#
# * F-β 得分
# ![F-%CE%B2.jpg](attachment:F-%CE%B2.jpg)
# ![F-%CE%B2%E8%AF%B4%E6%98%8E.jpg](attachment:F-%CE%B2%E8%AF%B4%E6%98%8E.jpg)
#
# * ROC曲线 受试者工作曲线
# ![ROC.jpg](attachment:ROC.jpg)

# %% [markdown]
# ## 回归指标
# * 平均绝对误差  标准差
# ```
# from sklearn.metrics import mean_absolute_error
# from sklearn.linear_model import LinearRegression
# classifier = LinearRegression
# classifier.fit(X, y)
# guesses = classifier.predict(X)
# error = mean_absolute_error(y, guesses)
# ```
# * 均方误差 方差
# ```
# from sklearn.metrics import mean_squared_error
# from sklearn.linear_model import LinearRegression
# classifier = LinearRegression
# classifier.fit(X, y)
# guesses = classifier.predict(X)
# error = mean_squared_error(y, guesses)
# ```
# * R2 SCORE
# ```
# r2 = 1-(线性回归模型的均方误差 / 简单模型的均方误差)
# r2 越接近1模型越好，越接近0模型越差
# from sklearn.metrics import r2_score
# y_true = [1, 2, 4]
# y_pred = [1.3, 2.5, 3.7]
# r2 = r2_score(y_true, y_pred)
# ```

# %% [markdown]
# * 模型复杂度曲线
# * K折交叉验证
# * 学习曲线
